# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – , tu revisor de confianza, también conocido como **"El Hesus que lleva la H de 'héroe' del código" 🦸‍♂️**. Sí, soy el único Hesus con H que te ayudará a llevar tu trabajo al siguiente nivel. Estoy preparado con observaciones y sugerencias que harán que tu proyecto destaque y esté a la altura de las mejores prácticas en desarrollo. ¡Prepárate para mejorar y brillar en el mundo del código! 🚀
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>

# %%
# Comenzare el proyecto cargando mis librerias necesarias

import pandas as pd
import sidetable as stb
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
# Cargo mi dataset
game_data = pd.read_csv("C:/Users/audre/OneDrive/Escritorio/tripletel/dataset_p6/games.csv")

# %%
# Ahora leere los datos basicos de mi dataset: 

def EDA (data):
    print(data.head())
    print()
    print(data.info())
    print()
    print('Filas duplicadas\n', data.duplicated().sum())
    print()
    print('Numero de datos nulos\n', data.isna().sum())

    
EDA(game_data)

# Mis observaciones
#Podemos ver que Las columnas con valores nulos son: Name, Year_of_Release, Genre, Critic_Score, User_Score, y Rating
# Hay que cambiar el formato de las columnas year_of_release y user_score segun un primer analisis
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# ...

# %%
# Utilizaremos sidetable para checar el numero de duplicados que tenemos en nuestras columnas y mas

game_data.stb.missing(style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_39b79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39b79_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_39b79_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_39b79_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39b79_level0_row0" class="row_heading level0 row0" >Critic_Score</th>
#       <td id="T_39b79_row0_col0" class="data row0 col0" >8,578</td>
#       <td id="T_39b79_row0_col1" class="data row0 col1" >16,715</td>
#       <td id="T_39b79_row0_col2" class="data row0 col2" >51.32%</td>
#     </tr>
#     <tr>
#       <th id="T_39b79_level0_row1" class="row_heading level0 row1" >Rating</th>
#       <td id="T_39b79_row1_col0" class="data row1 col0" >6,766</td>
#       <td id="T_39b79_row1_col1" class="data row1 col1" >16,715</td>
# ...

# %%
# Como primer paso de limpieza de datos ambiaremos los encabezados a minusculas
game_data.columns = game_data.columns.str.lower()
display(game_data.head())
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
# Hacemos labores de limpieza de datos: 
game_data['year_of_release'] = game_data['year_of_release'].fillna(0).astype(int)
game_data['name']=game_data['name'].fillna('unknown')
game_data['genre']=game_data['genre'].fillna('unknown') 
game_data['rating']=game_data['rating'].fillna('unknown') 

# Cambiamos el tipo de datos de la columna user_score la cual tiene valores tipo str 
game_data.loc[game_data['user_score']== 'tbd','user_score']=np.nan
game_data['user_score']=game_data['user_score'].astype(float)
game_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int32
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16715 non-null  object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.3+ MB

# %%
# Como primer analisis crearemos con una grafica hacia donde van nuestros valores atipicos
sns.boxplot(game_data['user_score'])
plt.show()

# %%
# Ya que la columna user_score ya ha sido convertida a float, procederemos a rellenar los valores faltantes con la media de los datos.
# (Este paso solo se realiza para temas de buen manejo de datos)

game_data['user_score'] = game_data['user_score'].fillna(game_data['user_score'].median())
print(game_data.info())  #confirmamos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int32
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       16715 non-null  float64
#  10  rating           16715 non-null  object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.3+ MB
# None

# %%
# Mismo pprocedimiento para critic_score, podemos ver los valores atipicos abajo
sns.boxplot(game_data['critic_score'])
plt.show()

# %%
game_data['critic_score'] = game_data['critic_score'].fillna(game_data['critic_score'].median())
print(game_data.info()) #confirmamos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int32
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     16715 non-null  float64
#  9   user_score       16715 non-null  float64
#  10  rating           16715 non-null  object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.3+ MB
# None

# %%
# Ya que las callificaciones en la columna rating son a traves de letras, esta columna la rellenaremos con el comentario unknown
game_data['rating'] = game_data['rating'].fillna('unknown')
game_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int32
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     16715 non-null  float64
#  9   user_score       16715 non-null  float64
#  10  rating           16715 non-null  object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.3+ MB

# %%
# Ya que estan limpios nuestros datos con las columnas correctas y sin datos nulos vamos a continuar 

# Agregamos una columna con nuestros datos de venta totales

game_data['total_sales']=game_data[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)

# Quiero esta columna a un lado de las ventas
total_sales_col = game_data.pop('total_sales')
game_data.insert(8, 'total_sales', total_sales_col)
game_data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  total_sales  critic_score  user_score  \
# 0     28.96      3.77         8.45        82.54          76.0         8.0
# 1      3.58      6.81         0.77        40.24          71.0         7.5
# 2     12.76      3.79         3.29        35.52          82.0         8.3
# 3     10.93      3.28         2.95        32.77          80.0         8.0
# 4      8.89     10.22         1.00        31.38          71.0         7.5
#
#     rating
# 0        E
# 1  unknown
# 2        E
# ...

# %%
# Ahora analizemos cuantos juegos se lanzan por año y quitamos los  que tienen un 0 en el año

games_by_yr=game_data.groupby('year_of_release').count()['name'].sort_values().reset_index()
games_by_yr = games_by_yr.query('year_of_release != 0') # para mi: recuerda el signo de ! para diferente de 0
games_by_yr.columns=['year_of_release','total_games']
games_by_yr.head(10)
# Out:
#    year_of_release  total_games
# 0             1980            9
# 1             1984           14
# 2             1985           14
# 3             1988           15
# 4             1987           16
# 5             1990           16
# 6             1983           17
# 7             1989           17
# 8             1986           21
# 9             1982           36

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Excelente trabajo! La selección de librerías es adecuada para el análisis exploratorio y visualización de datos. La carga del dataset se realizó correctamente, lo que establece una buena base para los análisis posteriores. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>

# %%
# Comenzamos a hacer un buen grafico para los juegos sacados por año
fig, ax = plt.subplots(figsize=(11, 6))

ax.vlines(x=games_by_yr.year_of_release, ymin=0, ymax=games_by_yr.total_games, color='purple',linewidth=10)
ax.set_title('Games Released Annually')
ax.set_xlabel('Year of release')
ax.set_ylabel('Number of games released')
ax.set_xticks(games_by_yr['year_of_release'].unique())
plt.xticks(rotation=60)

plt.show()

# Mis observaciones

# Se observa un crecimiento constante en las decadas de 1980 y 1990, con un aumento significativo a partir del año 2000 y un punto maximo entre 2008 y 2009 donde se lanzaron mas de 1400 juegos. 
# Sin embargo a partir de 2010 se nota una disminucion en la cantidad de lanzamientos

# %%
# Ahora haremos un grafico para las ventas de cada plataforma pero comenzamos agrupando nuestros datos principales

games_sales=game_data.groupby('platform')['total_sales'].sum().sort_values(ascending=False).reset_index()
display(games_sales.head(10))
# Out:
#   platform  total_sales
# 0      PS2      1255.77
# 1     X360       971.42
# 2      PS3       939.65
# 3      Wii       907.51
# 4       DS       806.12
# 5       PS       730.86
# 6      GBA       317.85
# 7      PS4       314.14
# 8      PSP       294.05
# 9       PC       259.52

# %%
plt.figure(figsize=(15, 6)) 
total_sales_graf = sns.barplot(data=games_sales, x="platform", y="total_sales", color='purple')
total_sales_graf.set(title='Most popular platforms', xlabel='platform', ylabel='Total Sales')
plt.xticks(rotation=60) 
plt.show()

# Mis observaciones:
# Podemos ver que PS2 cuenta con el primer lugar de ventas con mas de 1,200

# %%
# Obtendremos el zscore que es la distancia de la que  las ventas totales estan para con el average

games_sales['z_score']=(games_sales['total_sales']-games_sales['total_sales'].mean())/games_sales['total_sales'].std()
games_sales.head(10)
# Out:
#   platform  total_sales   z_score
# 0      PS2      1255.77  2.780807
# 1     X360       971.42  1.964085
# 2      PS3       939.65  1.872834
# 3      Wii       907.51  1.780520
# 4       DS       806.12  1.489304
# 5       PS       730.86  1.273139
# 6      GBA       317.85  0.086875
# 7      PS4       314.14  0.076219
# 8      PSP       294.05  0.018516
# 9       PC       259.52 -0.080663

# %%
games_sales['color']=['red' if puntaje < 0 else 'green' for puntaje in games_sales['z_score']]

# %%
#Graficamos como en clase y podemos ver que los valores en negativo son valores que estan por debajo de la media, mientras que los valores positivos son valores por encima de la media

plt.figure(figsize=(15,10))
plt.hlines(
    y=games_sales.platform, xmax=games_sales.z_score,xmin=0,linewidth=10,alpha=0.5, color=games_sales.color
)
plt.show()

# Mis observaciones
# Podemos ver que las mejores plataformas son las que estan por encima de la media de las ventas totales :)

# %%
# Ahora crearemos nuestra grafica donde podremos ver el historico de ventas por juego cada año
# Comenzamos con una tabla pivot solo del año 2011 en adelante como recomendacion del año

cleaned_data=game_data[game_data.year_of_release>=2011]
selected_games = ['PS2','X360', 'PS3', 'Wii','DS'] # las plataformas con mas ventas segun nuestra grafica anterior
full_table = cleaned_data.query("platform in @selected_games")
pivot=cleaned_data.pivot_table(index='year_of_release',columns='platform',values='total_sales',aggfunc='sum').fillna(0)
pivot


sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(data=pivot)
plt.title('Sells per platform')
plt.xlabel('Year of release')
plt.ylabel('Total Sells')
plt.show()

# Podemos observar que las plataformas tienden a durar 10 años

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! La visualización de lanzamientos de juegos por año está bien implementada, ofreciendo una perspectiva clara sobre la tendencia de crecimiento y declive en las últimas décadas. Observaste correctamente el pico en los años 2008-2009 y el posterior descenso en lanzamientos. Además, el análisis de ventas por plataforma y el cálculo de Z-score agregan profundidad, mostrando de manera efectiva qué plataformas están por encima o por debajo de la media en ventas. La segmentación de plataformas con mayores ventas y el gráfico de ventas por año desde 2011 son enfoques valiosos para entender el rendimiento histórico. Continúa aplicando estas buenas prácticas en futuras visualizaciones y análisis.
#
# </div>

# %%
# Ahora procederemos a calcular la covivarianza de los siguientes segmentos comenzando por el puntaje del usuario ya que queremos saber si entre mejor puntaje mas ventas

user_score_data = sns.scatterplot(data=full_table.dropna(), x='user_score', y='total_sales',hue='platform')
user_score_data.set(ylim=(0, 5))
user_score_data.set(title='Relation between user score and total sells', xlabel='User Score', ylabel='Total Sells')
plt.show()

print('La covarianza es de: ',np.cov(full_table['user_score'], full_table['total_sales'])[1,1])

# Mis observaciones
# cuando el puntaje de los usuarios aumenta, es probable que las ventas totales también aumenten ya que tenemos una covivarianza positiva
# Out:
# La covarianza es de:  1.9848908210009126

# %%
# datos por region

region = full_table.groupby("platform")[["na_sales", "eu_sales", "jp_sales"]].sum().reset_index()
print(region)
# Out:
#   platform  na_sales  eu_sales  jp_sales
# 0       DS     18.86      9.24      8.04
# 1      PS2      0.13      0.13      0.09
# 2      PS3    168.26    163.10     49.39
# 3      Wii     48.56     29.60      8.97
# 4     X360    226.80    117.10      3.35

# %%
critics_score_data = sns.scatterplot(data=full_table, x= 'critic_score', y= 'total_sales', hue= 'platform')
critics_score_data.set(ylim=(0, 5))
critics_score_data.set(title='Relation between sells and Crictics score', xlabel='Critics Score', ylabel='Total sells')
plt.show()

print('La covarianza es de: ',np.cov(full_table['critic_score'], full_table['total_sales'])[1,1])

# Mis observaciones
# cuando el puntaje de los criticos aumenta, es probable que las ventas totales también aumenten ya que tenemos una covivarianza positiva
# Out:
# La covarianza es de:  1.9848908210009126

# %%
caja = sns.boxplot(data= full_table, x="total_sales", hue= "platform")
caja.set(xlim=(0, 5))
caja.set(title='Sellings per platform', xlabel='Total Sales')
plt.show()

# Mis observaciones
# Las plataformas principales, como el PS3 y la X360, muestran medianas de ventas mas altas en comparación con las otras
# estos sistemas generaron mayores ventas en promedio

# %%
# Ya hemos analizado las ventas por plataforma, la relacion de las ventas con el puntaje del usuario y critico y las ventas, el tiempo de vida de los video juegos 

# Ahora procederemos a hacer un analisis por Genero de los juegos, region y calificacion
# Parami: Checa los markers del sprint pasado

genre = full_table.groupby('genre')[['na_sales', 'eu_sales', 'jp_sales']].sum().reset_index()
plt.figure(figsize=(14, 7))

sns.lineplot(data=genre, x='genre', y='na_sales', label='NA Sales', marker='s',color='blue')
sns.lineplot(data=genre, x='genre', y='eu_sales', label='EU Sales', marker='D',color='salmon')
sns.lineplot(data=genre, x='genre', y='jp_sales', label='JP Sales', marker='^',color='purple')

plt.title('Genre vs Location')
plt.xlabel('Genre')
plt.ylabel('Total Sells')
plt.legend(title='Location')
plt.show()
# Mis  observaciones

# se observa que el genero de accion tiene las ventas más altas
# Despues deportes y disparos en NA y EU pero en japon no

# %%
# Ahora analizaremos por plataforma solo considerando las mas populares

region=full_table.groupby('platform')[['na_sales', 'eu_sales', 'jp_sales']].sum().reset_index()
print(region)

plt.figure(figsize=(14, 7))
sns.lineplot(data=region, x='platform', y='na_sales', label='NA Sales', marker='s')
sns.lineplot(data=region, x='platform', y='eu_sales', label='EU Sales', marker='D')
sns.lineplot(data=region, x='platform', y='jp_sales', label='JP Sales', marker='^')

plt.title('Platform vs Sells')
plt.xlabel('Platform')
plt.ylabel('Total sells')
plt.legend(title='Region')
plt.show()
# Out:
#   platform  na_sales  eu_sales  jp_sales
# 0       DS     18.86      9.24      8.04
# 1      PS2      0.13      0.13      0.09
# 2      PS3    168.26    163.10     49.39
# 3      Wii     48.56     29.60      8.97
# 4     X360    226.80    117.10      3.35

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Observé que has incluido tus observaciones directamente en el código de varias gráficas, lo cual no es adecuado. En Jupyter Notebook, es preferible utilizar celdas Markdown para escribir observaciones, conclusiones y comentarios. Markdown permite separar el código del análisis descriptivo, lo que facilita la **reproducibilidad** y la lectura del notebook. La reproducibilidad significa que otras personas (o tú mismo en el futuro) podrán ejecutar y entender el flujo de trabajo fácilmente sin tener que interpretar comentarios dentro del código. Utilizar Markdown también permite dar formato al texto (como negritas, encabezados, listas), mejorando la presentación y claridad del análisis. Te recomiendo mover estas observaciones a celdas Markdown para mantener una estructura organizada y profesional en tu notebook.
#
# </div>

# %%
# Ahora analizaremos las ventas por rating en cada ubicacion

rating=full_table.groupby("rating")[["na_sales", "eu_sales", "jp_sales"]].sum().reset_index()
print(rating)

plt.figure(figsize=(14, 7))
sns.lineplot(data=rating,x='rating',y='na_sales' ,marker='s', label='NA Sales')
sns.lineplot(data=rating,x='rating',y='eu_sales', marker='D', label='EU Sales')
sns.lineplot(data=rating,x='rating', y='jp_sales',marker='^', label='JP Sales')

# Añadiendo títulos y etiquetas
plt.title('Sells vs Rating')
plt.xlabel('Rating')
plt.ylabel('Sells')
plt.legend(title='Location')


plt.show()

#Mis observaciones
#Podemos ver que las clasificaciones E Y M dominan en ventas, especialmente en NA
#Japon muestra una tendencia distinta lo cual podría deberse a factores culturales
# Out:
#     rating  na_sales  eu_sales  jp_sales
# 0        E     88.12     59.48      6.12
# 1     E10+     72.44     43.90      2.64
# 2       EC      0.42      0.00      0.00
# 3        M    196.23    137.09     16.82
# 4        T     61.01     38.30     15.74
# 5  unknown     44.39     40.40     28.52

# %%
# Procederemos a probar las siguientes hipotesis:

#Las calificaciones promedio de los usuarios para las plataformas Xbox One y PC son las mismas.

xbo = cleaned_data.loc[cleaned_data.platform == 'XOne', 'user_score'].dropna()
pc = cleaned_data.loc[cleaned_data.platform == 'PC', 'user_score'].dropna()

#Utilizaremos  la pruebla de levene como se vio en discord
alpha = 0.05
levene_test = st.levene(xbo, pc)
print(f'p-valor de Levene: {levene_test.pvalue}')

if levene_test.pvalue < alpha:
    t_test = st.ttest_ind(xbo, pc, equal_var=False)  #utilizamos twelch o tstudent segun comentario, recuerda true para el segundo
else:
    t_test = st.ttest_ind(xbo, pc, equal_var=True)

print(f"La p es de: {t_test.pvalue}")

if t_test.pvalue < alpha:
    print("Los puntajes si son diferentes entre usuarios de PC y Xbox One")
else:
    print("Los puntajes son iguales")
# Out:
# p-valor de Levene: 0.03721369305667955
# La p es de: 0.3361293822803634
# Los puntajes son iguales

# %%
# Graficamos la igualdad:
hip1 = cleaned_data[cleaned_data.platform.isin(['PC', 'XOne'])]
hip1_graf = sns.barplot(data=hip1, x="platform", y="user_score", hue="platform")
hip1_graf.set(title='XOne vs PC in Score', xlabel="Platform", ylabel='user score')
hip1_graf.set_ylim(0, 8)
plt.show()

# %%
# Procedemos a la siguiente hipotesis:
# Las calificaciones promedio de los usuarios para los géneros de Acción y Deportes son diferentes

# Comenzamos como antes
accion = cleaned_data.loc[cleaned_data.genre == 'Action', 'user_score'].dropna()
deportes = cleaned_data.loc[cleaned_data.genre == 'Sports', 'user_score'].dropna()

alpha = 0.05
levene_test = st.levene(accion, deportes)
print(f'p-valor de Levene: {levene_test.pvalue}')

if levene_test.pvalue < alpha:
    t_test = st.ttest_ind(accion,deportes, equal_var=False)   #de arriba
else:
    t_test = st.ttest_ind(accion,deportes, equal_var=True)

print(f'La p es de: {t_test.pvalue}')

if t_test.pvalue < alpha:
    print('Los puntajes si son diferentes entre los generos de Accion y Deportes')
else:
    print('Los puntajes son iguales')
# Out:
# p-valor de Levene: 7.200849104732042e-26
# La p es de: 2.6364667922335543e-18
# Los puntajes si son diferentes entre los generos de Accion y Deportes

# %%
hip2 = cleaned_data[cleaned_data.genre.isin(['Action', 'Sports'])]
hip2_graph = sns.barplot(data=hip2, x='genre', y='user_score', hue='genre')
hip2_graph.set(title='Action vs Sports in Rating', xlabel='Genre', ylabel='User score')
hip2_graph.set_ylim(0, 8)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Buen trabajo en esta sección! La implementación de la prueba de Levene para verificar la homogeneidad de varianzas entre grupos antes de aplicar el T-test es adecuada y muestra una sólida comprensión del análisis estadístico. También es positivo que consideres ambas variantes del T-test (Welch y Student) en función de los resultados de la prueba de Levene. Esto asegura que las pruebas sean precisas y se adapten a la distribución de los datos. Además, la visualización con gráficos de barras para comparar los puntajes promedio entre plataformas y géneros ayuda a interpretar los resultados y presenta las hipótesis de manera clara y efectiva. Continúa aplicando este enfoque sistemático en futuros análisis.
#
# </div>

# %% [markdown]
# Como conclusión del proyecto,
#
# El trabajo que hemos realizado en este proyecto fue una combinación entre limpieza y manejo de datos mas visualización y prueba de hipótesis.
#
# Una vez nuestros datos ya manejables agregamos una columna de las ventas totales a nuestra tabla ya que era necesaria para futuras operaciones.
#
# Posteriormente comenzamos nuestro análisis de juegos lanzados por año lo cual resulto en una grafica muy interesante donde logramos ver el crecimiento de lanzamiento de juegos y como llego a su pico a inicio de los años 2000 y como disminuyo posteriormente. Después de analizar las razones una de las mas importantes fue la entrada de los teléfonos celulares y la creación de juegos dentro de estos mismos.
#
# Al continuar con el análisis, logramos realizar otra grafica donde pudimos observar que la plataforma PS2 contaba con el primer lugar en ventas ya que podríamos señalar que marcó una gran innovación en las plataformas.
#
# Después, al hacer el histórico de ventas pudimos notar que el tiempo de vida de los juegos era de 10 años aproximadamente y también graficamos como se relacionaban los puntajes de los críticos y los usuarios con el numero  de ventas de cada videojuego y que  a mayor puntaje mejores ventas tendría el juego.
#
# Por ultimo, logramos ver cuales eran los géneros mas importantes para cada región lo cual resulto en un análisis bastante interesante ya que cada región tiene una cultura diferente y podemos ver los géneros preferidos por las tres regiones por igual y también aquellos en los que difieren.
#
# Por ejemplo, el genero mas alto para japon fue role-playing y accion mientras que para la unión europea y estados unidos los géneros mas altos fueron shooter y accion.
#
# Y para terminar, muestra prueba de hipótesis fue gracias a las pruebas de Twelch y Tstudent las cuales tomamos como referencia en acorde a las recomendaciones. Asi logramos graficar los puntajes y dar una representación visual como respaldo de la hipótesis que imprimimos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# El proyecto **puede ser aprobado**, ya que has demostrado un manejo sólido de técnicas de análisis de datos, visualización y pruebas de hipótesis. A continuación, te ofrezco algunos puntos de retroalimentación final para seguir mejorando tus habilidades:
#
# #### Puntos Fuertes:
# - **Limpieza y Preparación de Datos:** Excelente trabajo en la identificación y corrección de los tipos de datos, permitiendo un análisis fluido y preciso.
# - **Análisis Estadístico:** La implementación de pruebas estadísticas, como la prueba de Levene y T-test, está bien fundamentada y demuestra una comprensión clara de la comparación de medias. Las pruebas están correctamente integradas en el análisis.
# - **Visualización y Comparación:** Las gráficas utilizadas son efectivas para resaltar diferencias en plataformas y géneros, y el uso de Z-scores añade profundidad a la interpretación de las ventas en cada plataforma.
#
# #### Recomendaciones para Futuras Mejores:
# - **Celdas Markdown para Observaciones:** Recuerda usar celdas Markdown en lugar de comentarios dentro del código para registrar observaciones y conclusiones. Esto mejora la organización y facilita la reproducibilidad del análisis.
#
# ¡Felicidades por tu excelente trabajo y sigue así! 😊🚀
#
# </div>
